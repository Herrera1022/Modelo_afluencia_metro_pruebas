# %% [markdown]
# # Entrenamiento de un modelo de regresión

# %% [markdown]
# Librerías

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 1. Importación del dataset

# %%
df = pd.read_csv("./afluencia_metro_2024_transformado.csv")

# %%
df[df["misma_hora_semana_anterior"].isna()].groupby("fecha").size().unique()
# Out:
# array([], dtype=int64)

# %%
df[df["misma_hora_semana_anterior"].isna()].groupby("fecha").size()
# Out:
# fecha
# 2024-01-01    198
# 2024-01-02    230
# 2024-01-03    231
# 2024-01-04    230
# 2024-01-05    230
#              ...
# 2024-12-22      1
# 2024-12-23     10
# 2024-12-29      5
# 2024-12-30    230
# 2024-12-31    231
# Length: 145, dtype: int64
